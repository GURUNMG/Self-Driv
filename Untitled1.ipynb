# %%
guru="123"
_g_=90
k12=85
print(guru)
print(_g_)
print(k12)
# Out:
# 123
# 90
# 85

# %%
a='123'
print(type(a))
# Out:
# <class 'str'>

# %%
#conversion
b=int(a)
print(type(b))
# Out:
# <class 'int'>

# %%
c="ggg"
c=int(c)
print(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-47addddba4f2> in <module>
#       1 c="ggg"
# ----> 2 c=int(c)
#       3 print(c)
#
# ValueError: invalid literal for int() with base 10: 'ggg'

# %%
n=input()
# Out:
# 5

# %%
#number 1
num1=int(input())
# Out:
# 12

# %%
#number2
num2=float(input())
# Out:
# 45.2

# %%
print(num1+num2)
# Out:
# 57.2

# %%
'''m=15
for i in range(1,m):
    print(i)'''
# Out:
# 'm=15\nfor i in range(1,m):\n    print(i)'

# %%
print("hello world")
# Out:
# hello world
